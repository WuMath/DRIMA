# %%
library(Seurat)
# library(clustree)
library(cowplot)
library(data.table)
library(ggplot2)
library(patchwork)
library(stringr)
# library(qs)
library(Matrix)


data_root <- "/home/wuyan/dygmamba_project/NewRealPlan/Case1/process/"

traj <- "Bcell"

data_path <- paste0(data_root, traj, "/process/")

# The only need input are the atac_dir and rna_dir

atac_dir <- paste0(data_path,  "R/atac/")

rna_dir <- paste0(data_path,  "R/rna/")

############################################################################################
#******************************** Data Read --- ATAC ***************************************
############################################################################################

mtx <- readMM(paste0(atac_dir, "sparse.mtx"))

cellinfo <- fread(paste0(atac_dir, "cellinfo.csv"), header = T, data.table = F)

atacinfo <- fread(paste0(atac_dir, "atacinfo.csv"), header = T, data.table = F)

rownames(mtx) <- cellinfo$V1
colnames(mtx) <- atacinfo$V1

meta <- cellinfo
rownames(meta) <- cellinfo$V1

if(identical(rownames(meta), rownames(mtx))){
        # 行需为 feature
    print("Info identical, Can create Seurat Object")
    mtx_transposed <- t(mtx) 

    atac_seurat <- CreateSeuratObject(count = mtx_transposed, meta.data = meta, assay = "ATAC")
}

############################################################################################
#******************************** Data Read --- RNA ***************************************
############################################################################################


rna_mtx <- readMM(paste0(rna_dir, "sparse.mtx"))

rna_cellinfo <- fread(paste0(rna_dir, "cellinfo.csv"), header = T, data.table = F)

rna_info <- fread(paste0(rna_dir, "rnainfo.csv"), header = T, data.table = F)

rownames(rna_mtx) <- rna_cellinfo$V1
colnames(rna_mtx) <- rna_info$Geneid

meta <- rna_cellinfo
rownames(meta) <- rna_cellinfo$V1
 
print("Create Seurat Object")
rna_mtx_transposed <- t(rna_mtx)

rna_seurat <- CreateSeuratObject(count = rna_mtx_transposed, meta.data = meta, assay = "RNA")
# Out:
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: 'SeuratObject'
#
#
# The following objects are masked from 'package:base':
#
#     intersect, t
#
#
#
# Attaching package: 'patchwork'
#
#
# The following object is masked from 'package:cowplot':
#
#     align_plots
# [1] "Info identical, Can create Seurat Object"
# Warning message:
# "Data is of class dgTMatrix. Coercing to dgCMatrix."
# [1] "Create Seurat Object"
# Warning message:
# "Data is of class dgTMatrix. Coercing to dgCMatrix."

# %%
colnames(rna_seurat@meta.data)

rna_seurat@meta.data$cell_type
# Out:
#  [1] "orig.ident"               "nCount_RNA"
#  [3] "nFeature_RNA"             "V1"
#  [5] "GEX_pct_counts_mt"        "GEX_n_counts"
#  [7] "GEX_n_genes"              "GEX_size_factors"
#  [9] "GEX_phase"                "ATAC_nCount_peaks"
# [11] "ATAC_atac_fragments"      "ATAC_reads_in_peaks_frac"
# [13] "ATAC_blacklist_fraction"  "ATAC_nucleosome_signal"
# [15] "cell_type"                "batch"
# [17] "ATAC_pseudotime_order"    "GEX_pseudotime_order"
# [19] "Samplename"               "Site"
# [21] "DonorNumber"              "Modality"
# [23] "VendorLot"                "DonorID"
# [25] "DonorAge"                 "DonorBMI"
# [27] "DonorBloodType"           "DonorRace"
# [29] "Ethnicity"                "DonorGender"
# [31] "QCMeds"                   "DonorSmoker"
# [33] "n_genes_by_counts"        "total_counts"
# [35] "total_counts_mt"          "pct_counts_mt"
# [37] "pseudotime"
#    [1] "B1 B"           "B1 B"           "B1 B"           "B1 B"
#    [5] "B1 B"           "B1 B"           "B1 B"           "B1 B"
#    [9] "B1 B"           "Naive CD20+ B"  "B1 B"           "B1 B"
#   [13] "B1 B"           "B1 B"           "B1 B"           "Naive CD20+ B"
#   [17] "B1 B"           "B1 B"           "B1 B"           "B1 B"
#   [21] "B1 B"           "Naive CD20+ B"  "B1 B"           "B1 B"
#   [25] "B1 B"           "B1 B"           "B1 B"           "B1 B"
#   [29] "B1 B"           "B1 B"           "B1 B"           "B1 B"
#   [33] "B1 B"           "B1 B"           "Naive CD20+ B"  "B1 B"
#   [37] "B1 B"           "Naive CD20+ B"  "Transitional B" "B1 B"
#   [41] "B1 B"           "B1 B"           "Naive CD20+ B"  "Naive CD20+ B"
#   [45] "Naive CD20+ B"  "Naive CD20+ B"  "B1 B"           "Naive CD20+ B"
#   [49] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#   [53] "B1 B"           "Lymph prog"     "Naive CD20+ B"  "B1 B"
#   [57] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#   [61] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#   [65] "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B" "Naive CD20+ B"
#   [69] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#   [73] "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B" "Naive CD20+ B"
#   [77] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#   [81] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#   [85] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#   [89] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#   [93] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#   [97] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [101] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [105] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [109] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [113] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [117] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "B1 B"
#  [121] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [125] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [129] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [133] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [137] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [141] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [145] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [149] "Naive CD20+ B"  "Transitional B" "Naive CD20+ B"  "Naive CD20+ B"
#  [153] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [157] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "B1 B"
#  [161] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [165] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [169] "B1 B"           "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [173] "Transitional B" "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [177] "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B" "Naive CD20+ B"
#  [181] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [185] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [189] "Transitional B" "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [193] "Naive CD20+ B"  "Naive CD20+ B"  "B1 B"           "B1 B"
#  [197] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [201] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [205] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [209] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [213] "Naive CD20+ B"  "Naive CD20+ B"  "B1 B"           "Naive CD20+ B"
#  [217] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [221] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [225] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B"
#  [229] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [233] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [237] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [241] "B1 B"           "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B"
#  [245] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B"
#  [249] "Naive CD20+ B"  "Transitional B" "Transitional B" "Naive CD20+ B"
#  [253] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [257] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [261] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [265] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [269] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [273] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "B1 B"
#  [277] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [281] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [285] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [289] "Transitional B" "Transitional B" "Naive CD20+ B"  "Naive CD20+ B"
#  [293] "Naive CD20+ B"  "Transitional B" "Naive CD20+ B"  "Transitional B"
#  [297] "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B" "Naive CD20+ B"
#  [301] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [305] "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B" "Naive CD20+ B"
#  [309] "Transitional B" "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B"
#  [313] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [317] "Transitional B" "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [321] "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B" "Transitional B"
#  [325] "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B" "Transitional B"
#  [329] "Transitional B" "Transitional B" "Transitional B" "Transitional B"
#  [333] "Naive CD20+ B"  "Transitional B" "Transitional B" "Transitional B"
#  [337] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [341] "Transitional B" "Transitional B" "Transitional B" "Naive CD20+ B"
#  [345] "Transitional B" "Naive CD20+ B"  "Transitional B" "Naive CD20+ B"
#  [349] "Transitional B" "Transitional B" "Transitional B" "Naive CD20+ B"
#  [353] "Transitional B" "Transitional B" "Naive CD20+ B"  "Naive CD20+ B"
#  [357] "Transitional B" "Transitional B" "Transitional B" "Naive CD20+ B"
#  [361] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [365] "Naive CD20+ B"  "Transitional B" "Transitional B" "Naive CD20+ B"
#  [369] "Naive CD20+ B"  "Transitional B" "Naive CD20+ B"  "Transitional B"
#  [373] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B"
#  [377] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B"
#  [381] "Transitional B" "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B"
#  [385] "Transitional B" "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B"
#  [389] "Transitional B" "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B"
#  [393] "Naive CD20+ B"  "Transitional B" "Naive CD20+ B"  "Transitional B"
#  [397] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [401] "Transitional B" "Transitional B" "Naive CD20+ B"  "Transitional B"
#  [405] "Naive CD20+ B"  "Transitional B" "Naive CD20+ B"  "Transitional B"
#  [409] "Lymph prog"     "Transitional B" "Transitional B" "Transitional B"
#  [413] "Transitional B" "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [417] "Transitional B" "Transitional B" "Transitional B" "Naive CD20+ B"
#  [421] "Transitional B" "Naive CD20+ B"  "Transitional B" "Transitional B"
#  [425] "Transitional B" "B1 B"           "Transitional B" "Naive CD20+ B"
#  [429] "Transitional B" "Transitional B" "Transitional B" "Transitional B"
#  [433] "Transitional B" "Transitional B" "Transitional B" "Transitional B"
#  [437] "Transitional B" "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [441] "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B" "Naive CD20+ B"
#  [445] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [449] "Naive CD20+ B"  "Lymph prog"     "Transitional B" "Transitional B"
#  [453] "Naive CD20+ B"  "Lymph prog"     "Transitional B" "Transitional B"
#  [457] "Naive CD20+ B"  "Transitional B" "Transitional B" "Transitional B"
#  [461] "Transitional B" "Transitional B" "Transitional B" "Transitional B"
#  [465] "Transitional B" "Transitional B" "Transitional B" "Transitional B"
#  [469] "Transitional B" "Transitional B" "Transitional B" "Transitional B"
#  [473] "Transitional B" "Transitional B" "Transitional B" "Transitional B"
#  [477] "Transitional B" "Transitional B" "Transitional B" "Transitional B"
#  [481] "Transitional B" "Transitional B" "Transitional B" "Transitional B"
#  [485] "Transitional B" "Transitional B" "Transitional B" "Transitional B"
#  [489] "Transitional B" "Transitional B" "Transitional B" "Transitional B"
#  [493] "Transitional B" "Transitional B" "Transitional B" "B1 B"
#  [497] "Transitional B" "B1 B"           "Transitional B" "B1 B"
#  [501] "Transitional B" "Transitional B" "Naive CD20+ B"  "B1 B"
#  [505] "B1 B"           "Lymph prog"     "Naive CD20+ B"  "Naive CD20+ B"
#  [509] "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B" "B1 B"
#  [513] "Transitional B" "Naive CD20+ B"  "Transitional B" "B1 B"
#  [517] "B1 B"           "Transitional B" "Transitional B" "Transitional B"
#  [521] "Transitional B" "Transitional B" "Transitional B" "Transitional B"
#  [525] "Transitional B" "Naive CD20+ B"  "Naive CD20+ B"  "Transitional B"
#  [529] "Lymph prog"     "B1 B"           "Transitional B" "Lymph prog"
#  [533] "Naive CD20+ B"  "B1 B"           "Transitional B" "B1 B"
#  [537] "Lymph prog"     "B1 B"           "B1 B"           "Lymph prog"
#  [541] "B1 B"           "Transitional B" "Transitional B" "Transitional B"
#  [545] "Transitional B" "Naive CD20+ B"  "Lymph prog"     "Transitional B"
#  [549] "Transitional B" "Transitional B" "Naive CD20+ B"  "Transitional B"
#  [553] "B1 B"           "Naive CD20+ B"  "B1 B"           "B1 B"
#  [557] "Transitional B" "Lymph prog"     "Transitional B" "Naive CD20+ B"
#  [561] "B1 B"           "Lymph prog"     "B1 B"           "Transitional B"
#  [565] "Transitional B" "Transitional B" "Transitional B" "Transitional B"
#  [569] "Transitional B" "B1 B"           "Lymph prog"     "Transitional B"
#  [573] "B1 B"           "B1 B"           "Transitional B" "Transitional B"
#  [577] "B1 B"           "B1 B"           "B1 B"           "Lymph prog"
#  [581] "Lymph prog"     "B1 B"           "B1 B"           "Lymph prog"
#  [585] "B1 B"           "Lymph prog"     "B1 B"           "Transitional B"
#  [589] "B1 B"           "Transitional B" "B1 B"           "Transitional B"
#  [593] "Lymph prog"     "Lymph prog"     "B1 B"           "B1 B"
#  [597] "Lymph prog"     "Transitional B" "Lymph prog"     "Lymph prog"
#  [601] "B1 B"           "Lymph prog"     "Transitional B" "Transitional B"
#  [605] "B1 B"           "Transitional B" "Lymph prog"     "Naive CD20+ B"
#  [609] "Lymph prog"     "B1 B"           "Transitional B" "Lymph prog"
#  [613] "Lymph prog"     "B1 B"           "Lymph prog"     "Lymph prog"
#  [617] "Transitional B" "Lymph prog"     "B1 B"           "Lymph prog"
#  [621] "Lymph prog"     "Lymph prog"     "B1 B"           "B1 B"
#  [625] "B1 B"           "Transitional B" "Lymph prog"     "Transitional B"
#  [629] "Lymph prog"     "B1 B"           "Lymph prog"     "Naive CD20+ B"
#  [633] "B1 B"           "B1 B"           "Transitional B" "Lymph prog"
#  [637] "Lymph prog"     "B1 B"           "Lymph prog"     "Lymph prog"
#  [641] "Lymph prog"     "B1 B"           "B1 B"           "Lymph prog"
#  [645] "Lymph prog"     "Transitional B" "Naive CD20+ B"  "Transitional B"
#  [649] "Naive CD20+ B"  "Lymph prog"     "Lymph prog"     "Lymph prog"
#  [653] "Lymph prog"     "Naive CD20+ B"  "B1 B"           "Lymph prog"
#  [657] "Lymph prog"     "B1 B"           "Lymph prog"     "B1 B"
#  [661] "Lymph prog"     "B1 B"           "Lymph prog"     "B1 B"
#  [665] "Lymph prog"     "Lymph prog"     "Transitional B" "B1 B"
#  [669] "B1 B"           "B1 B"           "Lymph prog"     "Lymph prog"
#  [673] "Lymph prog"     "B1 B"           "B1 B"           "B1 B"
#  [677] "B1 B"           "B1 B"           "Lymph prog"     "B1 B"
#  [681] "Lymph prog"     "Lymph prog"     "Transitional B" "B1 B"
#  [685] "B1 B"           "Lymph prog"     "B1 B"           "B1 B"
#  [689] "B1 B"           "B1 B"           "B1 B"           "B1 B"
#  [693] "B1 B"           "B1 B"           "B1 B"           "B1 B"
#  [697] "B1 B"           "Lymph prog"     "B1 B"           "B1 B"
#  [701] "Lymph prog"     "Lymph prog"     "B1 B"           "Lymph prog"
#  [705] "B1 B"           "Lymph prog"     "Lymph prog"     "Lymph prog"
#  [709] "Lymph prog"     "B1 B"           "B1 B"           "B1 B"
#  [713] "B1 B"           "B1 B"           "B1 B"           "Lymph prog"
#  [717] "B1 B"           "HSC"            "HSC"            "B1 B"
#  [721] "Lymph prog"     "Lymph prog"     "Lymph prog"     "Lymph prog"
#  [725] "B1 B"           "B1 B"           "Lymph prog"     "Lymph prog"
#  [729] "B1 B"           "Transitional B" "Lymph prog"     "Lymph prog"
#  [733] "Transitional B" "Lymph prog"     "Lymph prog"     "HSC"
#  [737] "Lymph prog"     "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [741] "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"  "Naive CD20+ B"
#  [745] "Lymph prog"     "Lymph prog"     "Lymph prog"     "Naive CD20+ B"
#  [749] "Lymph prog"     "Lymph prog"     "Lymph prog"     "Lymph prog"
#  [753] "Lymph prog"     "Lymph prog"     "Lymph prog"     "Lymph prog"
#  [757] "HSC"            "Lymph prog"     "Lymph prog"     "Lymph prog"
#  [761] "Lymph prog"     "Lymph prog"     "Lymph prog"     "Lymph prog"
#  [765] "Lymph prog"     "Lymph prog"     "Lymph prog"     "HSC"
#  [769] "Lymph prog"     "HSC"            "Lymph prog"     "Lymph prog"
#  [773] "HSC"            "HSC"            "Lymph prog"     "Lymph prog"
#  [777] "Lymph prog"     "Lymph prog"     "Lymph prog"     "Lymph prog"
#  [781] "Lymph prog"     "Lymph prog"     "Lymph prog"     "Lymph prog"
#  [785] "Lymph prog"     "Lymph prog"     "Lymph prog"     "Lymph prog"
#  [789] "Lymph prog"     "Lymph prog"     "Lymph prog"     "Lymph prog"
#  [793] "Lymph prog"     "HSC"            "Lymph prog"     "HSC"
#  [797] "Lymph prog"     "HSC"            "Lymph prog"     "Lymph prog"
#  [801] "Lymph prog"     "Lymph prog"     "Lymph prog"     "Lymph prog"
#  [805] "HSC"            "HSC"            "HSC"            "HSC"
#  [809] "HSC"            "Lymph prog"     "HSC"            "HSC"
#  [813] "Lymph prog"     "HSC"            "Lymph prog"     "HSC"
#  [817] "HSC"            "HSC"            "Naive CD20+ B"  "HSC"
#  [821] "HSC"            "HSC"            "HSC"            "HSC"
#  [825] "B1 B"           "HSC"            "Lymph prog"     "HSC"
#  [829] "Lymph prog"     "HSC"            "HSC"            "HSC"
#  [833] "HSC"            "HSC"            "HSC"            "HSC"
#  [837] "HSC"            "HSC"            "HSC"            "HSC"
#  [841] "HSC"            "HSC"            "HSC"            "HSC"
#  [845] "HSC"            "HSC"            "HSC"            "HSC"
#  [849] "HSC"            "HSC"            "HSC"            "HSC"
#  [853] "HSC"            "HSC"            "HSC"            "HSC"
#  [857] "HSC"            "HSC"            "HSC"            "HSC"
#  [861] "HSC"            "HSC"            "HSC"            "HSC"
#  [865] "Lymph prog"     "Lymph prog"     "HSC"            "HSC"
#  [869] "HSC"            "HSC"            "HSC"            "HSC"
#  [873] "HSC"            "HSC"            "HSC"            "HSC"
#  [877] "HSC"            "HSC"            "HSC"            "HSC"
#  [881] "HSC"            "HSC"            "HSC"            "HSC"
#  [885] "HSC"            "HSC"            "HSC"            "Lymph prog"
#  [889] "HSC"            "HSC"            "HSC"            "HSC"
#  [893] "HSC"            "HSC"            "HSC"            "HSC"
#  [897] "HSC"            "HSC"            "HSC"            "HSC"
#  [901] "HSC"            "HSC"            "HSC"            "HSC"
#  [905] "HSC"            "HSC"            "HSC"            "HSC"
#  [909] "HSC"            "HSC"            "HSC"            "HSC"
#  [913] "HSC"            "HSC"            "HSC"            "HSC"
#  [917] "HSC"            "HSC"            "HSC"            "HSC"
#  [921] "HSC"            "HSC"            "HSC"            "HSC"
#  [925] "HSC"            "HSC"            "HSC"            "HSC"
#  [929] "HSC"            "HSC"            "HSC"            "HSC"
#  [933] "HSC"            "HSC"            "HSC"            "HSC"
#  [937] "HSC"            "HSC"            "HSC"            "HSC"
#  [941] "HSC"            "HSC"            "HSC"            "HSC"
#  [945] "HSC"            "HSC"            "HSC"            "HSC"
#  [949] "HSC"            "HSC"            "HSC"            "HSC"
#  [953] "HSC"            "HSC"            "HSC"            "HSC"
#  [957] "HSC"            "HSC"            "HSC"            "HSC"
#  [961] "HSC"            "HSC"            "HSC"            "HSC"
#  [965] "HSC"            "HSC"            "HSC"            "HSC"
#  [969] "HSC"            "HSC"            "HSC"            "HSC"
#  [973] "HSC"            "HSC"            "HSC"            "HSC"
#  [977] "HSC"            "HSC"            "HSC"            "HSC"
#  [981] "HSC"            "HSC"            "HSC"            "HSC"
#  [985] "HSC"            "HSC"            "HSC"            "HSC"
#  [989] "HSC"            "HSC"            "HSC"            "HSC"
#  [993] "HSC"            "HSC"            "HSC"            "HSC"
#  [997] "HSC"            "HSC"            "HSC"            "HSC"
